# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, time, date
# %matplotlib inline

# %%
df = pd.read_csv('clima.csv')

# %%
df['FECHA'] = pd.to_datetime(df['FECHA'])

# %%
del df['ID_ESTACION.1']
df['ANO'] = df['FECHA'].apply(lambda x: x.year)

# %%
df.head()
# Out:
#    ID_ESTACION      FECHA  PREC  TMAX  TMIN   TMED  VMAX   VDIR  VMED   DMED  \
# 0        36174 2017-01-01   0.0  23.9  13.8  18.60   0.2  359.7  0.20  346.1
# 1        36174 2017-02-01   0.0  25.3  11.2  16.93   0.2  330.5  0.20  318.4
# 2        36174 2017-03-01   0.0  27.8   9.9  17.90   0.2  328.1  0.20  315.6
# 3        36174 2016-01-10   0.0  32.7  25.1  28.58   0.3  270.1  0.21  315.6
# 4        36174 2016-02-10   0.0  33.5  26.0  29.38   0.3  246.9  0.21  318.5
#
#       RAD    HUM  ETO   EVA  ID_ESTADO      NOMBRE  ACTIVO   ANO
# 0  345.32  79.90  2.1  3.29         24  5 HERMANOS       0  2017
# 1  440.75  72.44  2.9  4.31         24  5 HERMANOS       0  2017
# 2  447.67  72.07  3.0  4.49         24  5 HERMANOS       0  2017
# 3  502.77  78.23  4.5  4.17         24  5 HERMANOS       0  2016
# 4  511.60  78.83  4.4  4.23         24  5 HERMANOS       0  2016

# %%
df_heatmap = pd.core.frame.DataFrame({'COUNT' : df.reset_index().groupby('NOMBRE')['ANO'].value_counts()}).reset_index()
plt.figure(figsize=(20,40))
plt.title('Total')
sns.heatmap(df_heatmap.pivot_table(values='COUNT',index='NOMBRE',columns='ANO'),cmap='coolwarm',linecolor='white',linewidths=1,annot=True,fmt='g')

# %%
df_heatmap = pd.core.frame.DataFrame({'COUNT' : df.reset_index().dropna(subset=['PREC']).groupby('NOMBRE')['ANO'].value_counts()}).reset_index()
plt.figure(figsize=(20,40))
plt.title('Precipitación total (mm)')
sns.heatmap(df_heatmap.pivot_table(values='COUNT',index='NOMBRE',columns='ANO'),cmap='coolwarm',linecolor='white',linewidths=1,annot=True,fmt='g')

# %%
df_heatmap = pd.core.frame.DataFrame({'COUNT' : df.reset_index().dropna(subset=['TMAX']).groupby('NOMBRE')['ANO'].value_counts()}).reset_index()
plt.figure(figsize=(20,40))
plt.title('Temperatura máxima (°C)')
sns.heatmap(df_heatmap.pivot_table(values='COUNT',index='NOMBRE',columns='ANO'),cmap='coolwarm',linecolor='white',linewidths=1,annot=True,fmt='g')

# %%
df_heatmap = pd.core.frame.DataFrame({'COUNT' : df.reset_index().dropna(subset=['TMIN']).groupby('NOMBRE')['ANO'].value_counts()}).reset_index()
plt.figure(figsize=(20,40))
plt.title('Temperatura mínima (°C)')
sns.heatmap(df_heatmap.pivot_table(values='COUNT',index='NOMBRE',columns='ANO'),cmap='coolwarm',linecolor='white',linewidths=1,annot=True,fmt='g')

# %%
df_heatmap = pd.core.frame.DataFrame({'COUNT' : df.reset_index().dropna(subset=['TMED']).groupby('NOMBRE')['ANO'].value_counts()}).reset_index()
plt.figure(figsize=(20,40))
plt.title('Temperatura media (°C)')
sns.heatmap(df_heatmap.pivot_table(values='COUNT',index='NOMBRE',columns='ANO'),cmap='coolwarm',linecolor='white',linewidths=1,annot=True,fmt='g')

# %%
df_heatmap = pd.core.frame.DataFrame({'COUNT' : df.reset_index().dropna(subset=['VMAX']).groupby('NOMBRE')['ANO'].value_counts()}).reset_index()
plt.figure(figsize=(20,40))
plt.title('Velocidad del viento máxima (km/hr)')
sns.heatmap(df_heatmap.pivot_table(values='COUNT',index='NOMBRE',columns='ANO'),cmap='coolwarm',linecolor='white',linewidths=1,annot=True,fmt='g')

# %%
df_heatmap = pd.core.frame.DataFrame({'COUNT' : df.reset_index().dropna(subset=['VDIR']).groupby('NOMBRE')['ANO'].value_counts()}).reset_index()
plt.figure(figsize=(20,40))
plt.title('Dirección de la velocidad máxima del viento (grados azimut)')
sns.heatmap(df_heatmap.pivot_table(values='COUNT',index='NOMBRE',columns='ANO'),cmap='coolwarm',linecolor='white',linewidths=1,annot=True,fmt='g')

# %%
df_heatmap = pd.core.frame.DataFrame({'COUNT' : df.reset_index().dropna(subset=['VMED']).groupby('NOMBRE')['ANO'].value_counts()}).reset_index()
plt.figure(figsize=(20,40))
plt.title('Velocidad promedio del viento (km/hr)')
sns.heatmap(df_heatmap.pivot_table(values='COUNT',index='NOMBRE',columns='ANO'),cmap='coolwarm',linecolor='white',linewidths=1,annot=True,fmt='g')

# %%
df_heatmap = pd.core.frame.DataFrame({'COUNT' : df.reset_index().dropna(subset=['DMED']).groupby('NOMBRE')['ANO'].value_counts()}).reset_index()
plt.figure(figsize=(20,40))
plt.title('Dirección promedio del viento (grados azimut)')
sns.heatmap(df_heatmap.pivot_table(values='COUNT',index='NOMBRE',columns='ANO'),cmap='coolwarm',linecolor='white',linewidths=1,annot=True,fmt='g')

# %%
df_heatmap = pd.core.frame.DataFrame({'COUNT' : df.reset_index().dropna(subset=['RAD']).groupby('NOMBRE')['ANO'].value_counts()}).reset_index()
plt.figure(figsize=(20,40))
plt.title('Radiación Global (w/m2)')
sns.heatmap(df_heatmap.pivot_table(values='COUNT',index='NOMBRE',columns='ANO'),cmap='coolwarm',linecolor='white',linewidths=1,annot=True,fmt='g')

# %%
df_heatmap = pd.core.frame.DataFrame({'COUNT' : df.reset_index().dropna(subset=['HUM']).groupby('NOMBRE')['ANO'].value_counts()}).reset_index()
plt.figure(figsize=(20,40))
plt.title('Humedad relativa (%)')
sns.heatmap(df_heatmap.pivot_table(values='COUNT',index='NOMBRE',columns='ANO'),cmap='coolwarm',linecolor='white',linewidths=1,annot=True,fmt='g')

# %%
df_heatmap = pd.core.frame.DataFrame({'COUNT' : df.reset_index().dropna(subset=['ETO']).groupby('NOMBRE')['ANO'].value_counts()}).reset_index()
plt.figure(figsize=(20,40))
plt.title('Evapotranspiración de referencia (mm)')
sns.heatmap(df_heatmap.pivot_table(values='COUNT',index='NOMBRE',columns='ANO'),cmap='coolwarm',linecolor='white',linewidths=1,annot=True,fmt='g')

# %%
df_heatmap = pd.core.frame.DataFrame({'COUNT' : df.reset_index().dropna(subset=['EVA']).groupby('NOMBRE')['ANO'].value_counts()}).reset_index()
plt.figure(figsize=(20,40))
plt.title('Evaporación potencial (mm)')
sns.heatmap(df_heatmap.pivot_table(values='COUNT',index='NOMBRE',columns='ANO'),cmap='coolwarm',linecolor='white',linewidths=1,annot=True,fmt='g')
